# %% [markdown]
# # User Behavior in an Educational Social Network (Part 2)

# %% [markdown]
# Continuing with the excercise, we have to determine which fields of the dataset are important for our objective of analyze what the users are accessing and how they do that.

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# With the help of mongo shell we can explore the values contained in a key, for example the field "custom_4" definitely contains valuable information:

# %% [markdown]
# `MongoDB Enterprise > db.events.distinct('custom_4')
# [ "Casual User", "Cold User", "Core User", "New User", "unknown", "yes" ]`

# %% [markdown]
# Here a sumary of the field contents:

# %% [markdown]
# | Field               |                             Example values                            |
# |:-------------------:|:---------------------------------------------------------------------:|
# | at                  |  "2017-11-16 19:00:00", "2017-11-16 19:00:04", "2017-11-16 19:00:12"  |
# | browser             |                                                                       |
# | carrier             |                                                                       |
# | city_name           |                                                                       |
# | clv_total           |                                                                       |
# | country             |                                                                       |
# | custom_1            |                                                                       |
# | custom_2            |                                                                       |
# | custom_3            |                                                                       |
# | custom_4            | "Casual User", "Cold User", "Core User", "New User" |
# | device_new          |                                                                       |
# | first-accessed-page |                                                                       |
# | install_uuid        |                                                                       |
# | language            |                                                                       |
# | Last Accessed Url   |                                                                       |
# | library_ver         |                                                                       |
# | marketing_campaign  |                                                                       |
# | marketing_medium    |                                                                       |
# | marketing_source    |                                                                       |
# | model               |                                                                       |
# | name                |                                                                       |
# | nth                 |                                                                       |
# | os_ver              |                                                                       |
# |                     |                                                                       |
# |                     |                                                                       |
